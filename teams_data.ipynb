# %% [markdown]
# ### Data Collection - Teams¶

# %% [markdown]
# ---

# %%
import pandas as pd
from functools import reduce

from app.scrapers.whoscored.league import get_league_stats_by_team

# %%
epl_df = get_league_stats_by_team(league_name='Premier League', league_data='./league/Premier League.csv')

# %%
epl_df
# Out:
#             team_name total_games goals yellow red ball_possession  \
# 0             Arsenal          12    26     16   2            61.0
# 1         Aston Villa          12    29     28   0            53.6
# 2         Bournemouth          12    11     20   1            42.2
# 3           Brentford          12    19     30   0            47.6
# 4            Brighton          12    25     30   1            61.9
# 5             Burnley          12     9     23   3            49.6
# 6             Chelsea          12    21     40   1            60.5
# 7      Crystal Palace          12    12     22   0            43.2
# 8             Everton          12    14     23   1            39.2
# 9              Fulham          12    10     31   2            48.8
# 10          Liverpool          12    27     20   4            58.6
# 11              Luton          12    10     20   0            35.4
# 12    Manchester City          12    32     22   2            62.5
# ...
